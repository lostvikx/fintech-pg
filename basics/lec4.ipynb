# %%
import pandas as pd
import os
import numpy as np

# %%
data_dir = os.getcwd() + "/data"
print(data_dir)

# df = pd.DataFrame()

df = pd.read_excel(data_dir + "/gapminder_full.xlsx")
df  # reads sheet1 by default
# Out:
# /home/vik/Documents/pgdm/sem2/finance-py/data
#      index      country  year  population  life exp     gdp_cap
# 0     1001  Afghanistan  1952   8425333.0    28.801  779.445314
# 1     1002  Afghanistan  1957   9240934.0       NaN  820.853030
# 2     1003  Afghanistan  1962  10267083.0    31.997  853.100710
# 3     1004  Afghanistan  1967  11537966.0    34.020  836.197138
# 4     1005  Afghanistan  1972  13079460.0    36.088  739.981106
# ..     ...          ...   ...         ...       ...         ...
# 558   1559       Gambia  1982    715523.0    45.580  835.809611
# 559   1560       Gambia  1987    848406.0    49.265  611.658861
# 560   1561       Gambia  1992   1025384.0    52.644  665.624413
# 561   1562       Gambia  1997   1235767.0    55.861  653.730170
# 562   1563       Gambia  2002   1457766.0    58.041         NaN
#
# [563 rows x 6 columns]

# %% [markdown]
# `os.chdir("/home/vik/Documents/code-py/")` -> Used to change directory, if you want to access a file in a different directory.

# %%
sheet1 = pd.read_excel(data_dir + "/gapminder_full.xlsx", sheet_name="data1")

# Find signature
# ?pd.read_excel
sheet1
# Out:
#      index      country  year  population  life exp     gdp_cap
# 0     1001  Afghanistan  1952   8425333.0    28.801  779.445314
# 1     1002  Afghanistan  1957   9240934.0       NaN  820.853030
# 2     1003  Afghanistan  1962  10267083.0    31.997  853.100710
# 3     1004  Afghanistan  1967  11537966.0    34.020  836.197138
# 4     1005  Afghanistan  1972  13079460.0    36.088  739.981106
# ..     ...          ...   ...         ...       ...         ...
# 558   1559       Gambia  1982    715523.0    45.580  835.809611
# 559   1560       Gambia  1987    848406.0    49.265  611.658861
# 560   1561       Gambia  1992   1025384.0    52.644  665.624413
# 561   1562       Gambia  1997   1235767.0    55.861  653.730170
# 562   1563       Gambia  2002   1457766.0    58.041         NaN
#
# [563 rows x 6 columns]

# %%
mapping_df = pd.read_csv(data_dir + "/mapping.csv")
mapping_df
# Out:
#            country:continent
# 0           Afghanistan:Asia
# 1             Albania:Europe
# 2             Algeria:Africa
# 3              Angola:Africa
# 4         Argentina:Americas
# ..                       ...
# 137             Vietnam:Asia
# 138  West Bank and Gaza:Asia
# 139         Yemen, Rep.:Asia
# 140            Zambia:Africa
# 141          Zimbabwe:Africa
#
# [142 rows x 1 columns]

# %%
df.head() # default arg: n=5
# Out:
#    index      country  year  population  life exp     gdp_cap
# 0   1001  Afghanistan  1952   8425333.0    28.801  779.445314
# 1   1002  Afghanistan  1957   9240934.0       NaN  820.853030
# 2   1003  Afghanistan  1962  10267083.0    31.997  853.100710
# 3   1004  Afghanistan  1967  11537966.0    34.020  836.197138
# 4   1005  Afghanistan  1972  13079460.0    36.088  739.981106

# %%
sheet1_des = sheet1.describe()

# %%
sheet1.columns
# Out:
# Index(['index', 'country', 'year', 'population', 'life exp', 'gdp_cap'], dtype='object')

# %%
sheet1.index
# Out:
# RangeIndex(start=0, stop=563, step=1)

# %%
sheet1.count()
# Out:
# index         563
# country       563
# year          563
# population    554
# life exp      560
# gdp_cap       561
# dtype: int64

# %%
len(sheet1)
# Out:
# 563

# %%
# sheet1.set_index("index", inplace=True)

# %%
sheet1.head()
# Out:
#    index      country  year  population  life exp     gdp_cap
# 0   1001  Afghanistan  1952   8425333.0    28.801  779.445314
# 1   1002  Afghanistan  1957   9240934.0       NaN  820.853030
# 2   1003  Afghanistan  1962  10267083.0    31.997  853.100710
# 3   1004  Afghanistan  1967  11537966.0    34.020  836.197138
# 4   1005  Afghanistan  1972  13079460.0    36.088  739.981106

# %%
sheet1 = pd.read_excel(data_dir + "/gapminder_full.xlsx", sheet_name=0, index_col=0)
# This method is more clear.
sheet2 = pd.read_excel(data_dir + "/gapminder_full.xlsx", sheet_name="data2", index_col="index")
sheet2.head()
# Out:
#        country  year  population  life exp       gdp_cap
# index
# 1564    Gambia  2007         NaN       NaN    752.749726
# 1565   Germany  1952  69145952.0      67.5   7144.114393
# 1566   Germany  1957  71019069.0      69.1  10187.826650
# 1567   Germany  1962  73739117.0      70.3  12902.462910
# 1568   Germany  1967  76368453.0      70.8  14745.625610

# %%
pd.read_csv("./data/mapping.csv")
# Out:
#            country:continent
# 0           Afghanistan:Asia
# 1             Albania:Europe
# 2             Algeria:Africa
# 3              Angola:Africa
# 4         Argentina:Americas
# ..                       ...
# 137             Vietnam:Asia
# 138  West Bank and Gaza:Asia
# 139         Yemen, Rep.:Asia
# 140            Zambia:Africa
# 141          Zimbabwe:Africa
#
# [142 rows x 1 columns]

# %%
sheet1["population"]
# Out:
# index
# 1001     8425333.0
# 1002     9240934.0
# 1003    10267083.0
# 1004    11537966.0
# 1005    13079460.0
#            ...
# 1559      715523.0
# 1560      848406.0
# 1561     1025384.0
# 1562     1235767.0
# 1563     1457766.0
# Name: population, Length: 563, dtype: float64

# %%
sheet1.columns
# Out:
# Index(['country', 'year', 'population', 'life exp', 'gdp_cap'], dtype='object')

# %%
year_gdp = sheet1[["year", "gdp_cap"]]

# %%
# year_gdp.to_clipboard()

# %%
# sheet1.set_index("index", inplace=True)

# %%
sheet1.loc[1005, "country"]
# Out:
# 'Afghanistan'

# %% [markdown]
# We can specify multiple indeices we want, as well as the specific column names by using lists instead.

# %%
sheet1.loc[[1005, 1045], ["country", "life exp", "gdp_cap"]]
# Out:
#            country  life exp      gdp_cap
# index
# 1005   Afghanistan    36.088   739.981106
# 1045        Angola    40.647  2627.845685

# %% [markdown]
# Using a colon instead gets us the entire range of values specified.

# %%
sheet1.loc[1005:1010, "country":"gdp_cap"]
# Out:
#            country  year  population  life exp     gdp_cap
# index
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106
# 1006   Afghanistan  1977  14880372.0    38.438  786.113360
# 1007   Afghanistan  1982         NaN    39.854  978.011439
# 1008   Afghanistan  1987  13867957.0    40.822  852.395945
# 1009   Afghanistan  1992  16317921.0    41.674  649.341395
# 1010   Afghanistan  1997  22227415.0    41.763  635.341351

# %%
sheet1.loc[(sheet1["gdp_cap"] > 30000) & (sheet1["country"] == "Australia")]
# sheet1.info()
# Out:
#          country  year  population  life exp      gdp_cap
# index
# 1071   Australia  2002  19546792.0    80.370  30687.75473
# 1072   Australia  2007  20434176.0    81.235  34435.36744

# %% [markdown]
# Let's say we want to skip population column.

# %%
# sheet1.columns != "population"  # [True, True, False, True, True]

sheet1.loc[1500:1505, sheet1.columns != "population"]
# Out:
#         country  year  life exp     gdp_cap
# index
# 1500    Eritrea  1987    46.453  521.134133
# 1501    Eritrea  1992    49.991  582.858510
# 1502    Eritrea  1997    53.378  913.470790
# 1503    Eritrea  2002    55.240  765.350001
# 1504    Eritrea  2007    58.040  641.369524
# 1505   Ethiopia  1952    34.078  362.146280

# %%
sheet1.loc[1100:1105, ~ sheet1.columns.isin(["population", "year"])]
# Out:
#           country  life exp     gdp_cap
# index
# 1100   Bangladesh    43.453  721.186086
# 1101   Bangladesh    45.252  630.233627
# 1102   Bangladesh    46.923  659.877232
# 1103   Bangladesh    50.009  676.981866
# 1104   Bangladesh    52.819  751.979403
# 1105   Bangladesh    56.018  837.810164

# %%
combined = sheet1.append(sheet2)
# combined

# %% [markdown]
# `axis=0` stack (concat) data with similar columns, it can add new columns
#
# `axis=1` stack (concat) data with similar rows, it can add new rows

# %%
new_combined = pd.concat([sheet1, sheet2], axis=0)
new_combined.head()
# Out:
#            country  year  population  life exp     gdp_cap
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106

# %%
# new_combined.reset_index() # reset index
new_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 1001 to 2704
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1669 non-null   float64
#  3   life exp    1687 non-null   float64
#  4   gdp_cap     1699 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 79.9+ KB

# %% [markdown]
# Format = `lambda input : output`

# %%
muli_add = lambda x, y, z: x * y + z
print(muli_add(5, 8, 2))

(lambda x: x**2)(5)
# Out:
# 42
# 25

# %%
l_func = lambda y, fun1, fun2: y + fun1(y) + fun2(y)
l_func(3, lambda x: x**4, lambda x: x**2)
# Out:
# 93

# %%
test_arr = [12, 13, 14]
list(map(lambda x: x**2, test_arr))

country_test = ["India:Asia", "Japan:Asia", "Germany:Europe"]
list(map(lambda val: val.split(":")[0], country_test))
# Out:
# ['India', 'Japan', 'Germany']

# %%
test_num_arr = [1, -5, 6, -10]
list(filter(lambda x: x > 0, test_num_arr))
# Out:
# [1, 6]

# %%
# mapping_df["country"] = mapping_df.iloc[:, 0].map(lambda val: val.split(":")[0])
# mapping_df["continent"] = mapping_df.iloc[:, 1].map(lambda val: val.split(":")[1])

# Two ways to delete columns
# del mapping_df["country:continent"]
# mapping_df.drop(mapping_df.columns[0], inplace=True)
mapping_df.head()
# mapping_df.columns
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3       Angola    Africa
# 4    Argentina  Americas

# %%
merged_df = pd.merge(new_combined, mapping_df, on="country", how="left")
# print(new_combined)
# print(merged_df)
# OR
# merged_df = new_combined.merge(mapping_df, on="country", how="left")

merged_df = merged_df.set_index(new_combined.index)

# %%
# merged_df.info()
merged_df.head()
# Out:
#            country  year  population  life exp     gdp_cap continent
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia

# %%
merged_df["continent"].unique()
# Series bool
asia = merged_df["continent"] == "Asia"
asian_countries = merged_df[asia]
asian_countries

merged_df[merged_df["year"] == 2002]

merged_df[merged_df["year"] == merged_df["year"].max()] # 2007
merged_df[merged_df["year"] == merged_df["year"].min()] # 1952
# Out:
#                   country  year  population  life exp      gdp_cap continent
# index
# 1001          Afghanistan  1952   8425333.0    28.801   779.445314      Asia
# 1013              Albania  1952   1282697.0    55.230  1601.056136    Europe
# 1025              Algeria  1952   9279525.0    43.077  2449.008185    Africa
# 1037               Angola  1952   4232095.0    30.015  3520.610273    Africa
# 1049            Argentina  1952  17876956.0    62.485  5911.315053  Americas
# ...                   ...   ...         ...       ...          ...       ...
# 2645              Vietnam  1952  26246839.0    40.412   605.066492      Asia
# 2657   West Bank and Gaza  1952   1030585.0    43.160  1515.592329      Asia
# 2669          Yemen, Rep.  1952   4963829.0    32.548   781.717576      Asia
# 2681               Zambia  1952   2672000.0    42.038  1147.388831    Africa
# 2693             Zimbabwe  1952   3080907.0    48.451   406.884115    Africa
#
# [142 rows x 6 columns]

# %% [markdown]
# ## Use parenthesis while using two or more conditionals.

# %%
merged_df[(merged_df["continent"] == "Asia") | (merged_df["continent"] == "Africe")]
# Same as the above
# merged_df[merged_df["continent"].isin(["Asia", "Africa"])]
# Out:
#            country  year  population  life exp      gdp_cap continent
# index
# 1001   Afghanistan  1952   8425333.0    28.801   779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN   820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997   853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020   836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088   739.981106      Asia
# ...            ...   ...         ...       ...          ...       ...
# 2676   Yemen, Rep.  1987  11219340.0    52.922  1971.741538      Asia
# 2677   Yemen, Rep.  1992  13367997.0    55.599  1879.496673      Asia
# 2678   Yemen, Rep.  1997  15826497.0    58.020  2117.484526      Asia
# 2679   Yemen, Rep.  2002  18701257.0    60.308  2234.820827      Asia
# 2680   Yemen, Rep.  2007  22211743.0    62.698  2280.769906      Asia
#
# [396 rows x 6 columns]

# %%
merged_df[(merged_df["continent"] == "Europe") & (merged_df["year"] == merged_df["year"].max())]
# Out:
#                       country  year  population  life exp       gdp_cap  \
# index
# 1024                  Albania  2007   3600523.0    76.423   5937.029526
# 1084                  Austria  2007   8199783.0    79.829  36126.492700
# 1120                  Belgium  2007  10392226.0    79.441  33692.605080
# 1156   Bosnia and Herzegovina  2007   4552198.0    74.852   7446.298803
# 1192                 Bulgaria  2007   7322858.0    73.005  10680.792820
# 1384                  Croatia  2007   4493312.0    75.748  14619.222720
# 1408           Czech Republic  2007  10228744.0    76.486  22833.308510
# 1420                  Denmark  2007   5468120.0    78.332  35278.418740
# 1528                  Finland  2007   5238460.0    79.313  33207.084400
# 1540                   France  2007  61083916.0    80.657  30470.016700
# 1576                  Germany  2007  82400996.0    79.406  32170.374420
# 1600                   Greece  2007  10706290.0    79.483  27538.411880
# ...

# %%
# merged_df.sort_values(by=["year"], ascending=False)
merged_df.sort_values(by=["country", "year"], ascending=[True, False], kind="mergesort")
# Out:
#            country  year  population  life exp     gdp_cap continent
# index
# 1012   Afghanistan  2007  31889923.0    43.828  974.580338      Asia
# 1011   Afghanistan  2002  25268405.0    42.129  726.734055      Asia
# 1010   Afghanistan  1997  22227415.0    41.763  635.341351      Asia
# 1009   Afghanistan  1992  16317921.0    41.674  649.341395      Asia
# 1008   Afghanistan  1987  13867957.0    40.822  852.395945      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2697      Zimbabwe  1972   5861135.0    55.635  799.362176    Africa
# 2696      Zimbabwe  1967   4995432.0    53.995  569.795071    Africa
# 2695      Zimbabwe  1962   4277736.0    52.358  527.272182    Africa
# 2694      Zimbabwe  1957   3646340.0    50.469  518.764268    Africa
# 2693      Zimbabwe  1952   3080907.0    48.451  406.884115    Africa
#
# [1704 rows x 6 columns]

# %%
#rename
merged_df = merged_df.rename({"population":"pop"}, axis="columns")
merged_df
# Out:
#            country  year         pop  life exp     gdp_cap continent
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2700      Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701      Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702      Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703      Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
# 2704      Zimbabwe  2007         NaN    43.487  469.709298    Africa
#
# [1704 rows x 6 columns]

# %%
# isNaN = merged_df.isna()
isNaN = merged_df.isna().any()
temp = merged_df.dropna(axis="columns", thresh=len(merged_df)*0.98) # drops pop
# Out:
#            country  year  life exp     gdp_cap continent
# index
# 1001   Afghanistan  1952    28.801  779.445314      Asia
# 1002   Afghanistan  1957       NaN  820.853030      Asia
# 1003   Afghanistan  1962    31.997  853.100710      Asia
# 1004   Afghanistan  1967    34.020  836.197138      Asia
# 1005   Afghanistan  1972    36.088  739.981106      Asia
# ...            ...   ...       ...         ...       ...
# 2700      Zimbabwe  1987    62.351  706.157306    Africa
# 2701      Zimbabwe  1992    60.377  693.420786    Africa
# 2702      Zimbabwe  1997    46.809  792.449960    Africa
# 2703      Zimbabwe  2002    39.989  672.038623    Africa
# 2704      Zimbabwe  2007    43.487  469.709298    Africa
#
# [1704 rows x 5 columns]

# %%
# Drop rows if found NaN in a record.
temp = merged_df.dropna(axis="index")
temp
# Out:
#            country  year         pop  life exp     gdp_cap continent
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
# 1006   Afghanistan  1977  14880372.0    38.438  786.113360      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2699      Zimbabwe  1982   7636524.0    60.363  788.855041    Africa
# 2700      Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701      Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702      Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703      Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
#
# [1650 rows x 6 columns]

# %% [markdown]
# ## Perform a deepcopy

# %%
df = merged_df.copy()
df
# Out:
#            country  year         pop  life exp     gdp_cap continent
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2700      Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701      Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702      Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703      Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
# 2704      Zimbabwe  2007         NaN    43.487  469.709298    Africa
#
# [1704 rows x 6 columns]

# %%
# df["pop"].fillna(0, inplace=True)
# methods: forward (prev val) and backward (next val)
# df["pop"].fillna(method="ffill", inplace=True)
df.tail()
# Out:
#         country  year         pop  life exp     gdp_cap continent
# index
# 2700   Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701   Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702   Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703   Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
# 2704   Zimbabwe  2007         NaN    43.487  469.709298    Africa

# %% [markdown]
# ## Loops
#
# Generally we don't use loops in data anlytics

# %%
for i, row in df.iterrows():
  print(i, row)
# Out:
# 1001 country      Afghanistan
# year                1952
# pop            8425333.0
# life exp          28.801
# gdp_cap       779.445314
# continent           Asia
# Name: 1001, dtype: object
# 1002 country      Afghanistan
# year                1957
# pop            9240934.0
# life exp             NaN
# gdp_cap        820.85303
# continent           Asia
# Name: 1002, dtype: object
# 1003 country      Afghanistan
# year                1962
# pop           10267083.0
# life exp          31.997
# gdp_cap        853.10071
# continent           Asia
# Name: 1003, dtype: object
# 1004 country      Afghanistan
# year                1967
# pop           11537966.0
# life exp           34.02
# gdp_cap       836.197138
# continent           Asia
# Name: 1004, dtype: object
# 1005 country      Afghanistan
# year                1972
# pop           13079460.0
# life exp          36.088
# gdp_cap       739.981106
# continent           Asia
# Name: 1005, dtype: object
# ...

# %%
for index, row in df.iterrows():
  if df.loc[index, "life exp"] > 50:
    df.loc[index, "life_check"] = "> 50"
  else:
    df.loc[index, "life_check"] = "<= 50"

# %%
df
# Out:
#            country  year         pop  life exp     gdp_cap continent  \
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2700      Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701      Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702      Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703      Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
# 2704      Zimbabwe  2007         NaN    43.487  469.709298    Africa
#
#       life_check
# index
# 1001       <= 50
# 1002       <= 50
# 1003       <= 50
# 1004       <= 50
# 1005       <= 50
# ...

# %%
df = df.rename({"life exp": "life_exp"}, axis=1)
df
# Out:
#            country  year         pop  life_exp     gdp_cap continent  \
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
# ...            ...   ...         ...       ...         ...       ...
# 2700      Zimbabwe  1987   9216418.0    62.351  706.157306    Africa
# 2701      Zimbabwe  1992  10704340.0    60.377  693.420786    Africa
# 2702      Zimbabwe  1997  11404948.0    46.809  792.449960    Africa
# 2703      Zimbabwe  2002  11926563.0    39.989  672.038623    Africa
# 2704      Zimbabwe  2007         NaN    43.487  469.709298    Africa
#
#       life_check
# index
# 1001       <= 50
# 1002       <= 50
# 1003       <= 50
# 1004       <= 50
# 1005       <= 50
# ...

# %%
print(df.columns)
for row in df.itertuples():
  print(row[3])
# Out:
# Index(['country', 'year', 'pop', 'life_exp', 'gdp_cap', 'continent',
#        'life_check'],
#       dtype='object')
# 8425333.0
# 9240934.0
# 10267083.0
# 11537966.0
# 13079460.0
# 14880372.0
# nan
# 13867957.0
# 16317921.0
# 22227415.0
# 25268405.0
# 31889923.0
# 1282697.0
# 1476505.0
# 1728137.0
# 1984060.0
# 2263554.0
# 2509048.0
# 2780097.0
# 3075321.0
# 3326498.0
# 3428038.0
# 3508512.0
# 3600523.0
# 9279525.0
# 10270856.0
# 11000948.0
# 12760499.0
# 14760787.0
# 17152804.0
# 20033753.0
# 23254956.0
# 26298373.0
# 29072015.0
# 31287142.0
# 33333216.0
# 4232095.0
# 4561361.0
# 4826015.0
# 5247469.0
# 5894858.0
# 6162675.0
# 7016384.0
# 7874230.0
# 8735988.0
# 9875024.0
# 10866106.0
# 12420476.0
# 17876956.0
# 19610538.0
# 21283783.0
# 22934225.0
# 24779799.0
# 26983828.0
# 29341374.0
# 31620918.0
# 33958947.0
# 36203463.0
# 38331121.0
# 40301927.0
# 8691212.0
# 9712569.0
# 10794968.0
# 11872264.0
# 13177000.0
# 14074100.0
# 15184200.0
# 16257249.0
# 17481977.0
# 18565243.0
# ...

# %%
import datetime

# %% [markdown]
# ### Calc time taken

# %%
start_time = datetime.now()

# %%
df.loc[df["life_exp"] > 50, "life_check2"] = "> 50"
df["life_check2"].fillna("<= 50", inplace=True)
df.head()
# Out:
#            country  year         pop  life_exp     gdp_cap continent  \
# index
# 1001   Afghanistan  1952   8425333.0    28.801  779.445314      Asia
# 1002   Afghanistan  1957   9240934.0       NaN  820.853030      Asia
# 1003   Afghanistan  1962  10267083.0    31.997  853.100710      Asia
# 1004   Afghanistan  1967  11537966.0    34.020  836.197138      Asia
# 1005   Afghanistan  1972  13079460.0    36.088  739.981106      Asia
#
#       life_check life_check2
# index
# 1001       <= 50       <= 50
# 1002       <= 50       <= 50
# 1003       <= 50       <= 50
# 1004       <= 50       <= 50
# 1005       <= 50       <= 50
